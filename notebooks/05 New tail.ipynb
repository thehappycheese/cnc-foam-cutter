# %%
import numpy as np
import pandas as pd

from airfoil import Airfoil, Hole, Decomposer, WingSegment, Decomposer

from airfoil.cnc._serial import CNC
from airfoil.util import (
    blur1d,
    map_to_range,
    remove_sequential_duplicates,
    deflection_angle_padded,
    project_line_to_plane,
    create_ruled_surface,
)
import pyvista as pv
pv.set_jupyter_backend('trame')

# %%
holes = [
    Hole(diameter_mm=5,position=np.array([50,2])),
    Hole(diameter_mm=5,position=np.array([100,2])),
]
afa = Airfoil.from_naca_designation("0012", chord_length=180).with_holes(holes)
afb = Airfoil.from_naca_designation("0012", chord_length=150).with_translation(np.array([30,3])).with_holes(holes)
ws1 = WingSegment(
    left=afa,
    right=afb,
    length=50
)
ws1.plot_2d()

# %%
from pathlib import Path
Path("./data/theplank/elevator_root_section.dxf").write_text(afa.to_dxf())

# %%
ws2 = WingSegment(
    left=afa,
    right=afa,
    length=50
)
ws2.plot_2d()

# %%
ws3 = WingSegment(
    left  = Airfoil.from_naca_designation("0012", chord_length=160),
    right = Airfoil.from_naca_designation("0012", chord_length=180).with_translation((-20,0)),
    length=150
)
ws3.plot_2d()

# %%
ws4 = WingSegment(
    left  = Airfoil.from_naca_designation("0012", chord_length=180),
    right = Airfoil.from_naca_designation("0012", chord_length=180),
    length= 50
)
ws4.plot_2d()

# %%
ws5 = WingSegment(
    left   = Airfoil.from_naca_designation("0012", chord_length=150)
        .with_translation((10,0)),
    right  = Airfoil.from_naca_designation("0012", chord_length=160),
    length = 80
)
WingSegment.plot_wing_segments([ws5,ws3]).show()

# %%
# Gotta cut a block of foam to support the tail in its clamp
# Will do that manually here which is a bit tedious, but it gives us better control over the travel/cut behavior.
downset = -20
holster = (
    Airfoil.from_naca_designation("0012", chord_length=180)
    .with_translation((10,downset))
)
pts = holster.to_polygon().buffer(-0.5)
main_cut = np.array(pts.boundary.coords)
ax,_ = holster.plot()
w=237
h=-36.5
rx=0
ry=0
ax.plot(*np.array([ # box
    [rx,ry],
    [rx+w,ry],
    [rx+w,ry+h],
    [rx,ry+h],
    [rx,ry],
]).transpose())


initial_travel = np.array([
    [0,0],
    [-5,0],
    [-5,30],
    [w+5,30],
    [w+5,downset],
])
cut_in = np.array([
    [w+5,downset],
    main_cut[0],
])
ax.plot(*initial_travel.transpose())
ax.plot(*cut_in.transpose())
ax.plot(*main_cut.transpose())
movement = remove_sequential_duplicates(np.concat([
    initial_travel,
    cut_in,
    main_cut
]))[1:]

main_cut_speed = map_to_range(deflection_angle_padded(main_cut),180,120)[:-2]
speeds = np.array([
    *np.full(len(initial_travel)-1,1000),
    *np.full(len(cut_in)-1,160),
    *main_cut_speed
])

from airfoil.cnc import GCodeBuilder
g = GCodeBuilder()

g=g.set_position(0,0,0,0)
g=g.path_absolute(
    xyza=np.tile(movement,(1,2)),
    feedrate=speeds,
    current=np.full(len(movement)-1, 1.85),
    compensate_feedrate=True,
)
g=g.set_current(0)
gcode = g.build()

# %%
# Gotta cut a block of foam to support the tail in its clamp
# Will do that manually here which is a bit tedious, but it gives us better control over the travel/cut behavior.
downset = -25
holster = (
    Airfoil.from_naca_designation("0012", chord_length=180)
    .with_translation((10,downset))
)
pts = holster.to_polygon().buffer(-0.5)
main_cut = np.array(pts.boundary.coords)[::-1]
ax,_ = holster.plot()
w=237
h=-50
rx=0
ry=0
ax.plot(*np.array([ # box
    [rx,ry],
    [rx+w,ry],
    [rx+w,ry+h],
    [rx,ry+h],
    [rx,ry],
]).transpose())


initial_travel = np.array([
    [0,0],
    [-5,0],
    [-5,30],
    [w+5,30],
    [w+5,downset],
])
cut_in = np.array([
    [w+5,downset],
    main_cut[0],
])
ax.plot(*initial_travel.transpose())
ax.plot(*cut_in.transpose())
ax.plot(*main_cut.transpose())
movement = remove_sequential_duplicates(np.concat([
    initial_travel,
    cut_in,
    main_cut
]))[1:]

main_cut_speed = map_to_range(deflection_angle_padded(main_cut),180,120)[:-2]
speeds = np.array([
    *np.full(len(initial_travel)-1,1000),
    *np.full(len(cut_in)-1,110),
    *main_cut_speed
])

from airfoil.cnc import GCodeBuilder
g = GCodeBuilder()

g=g.set_position(0,0,0,0)
g=g.path_absolute(
    xyza=np.tile(movement,(1,2)),
    feedrate=speeds,
    current=np.full(len(movement)-1, 1.85),
    compensate_feedrate=True,
)
g=g.set_current(0)
gcode = g.build()

# %%
# from airfoil.cnc import MachineSetup, CNC
# ms = MachineSetup(
#     wing_segment=ws2,
#     foam_depth=200,
#     foam_height=30,
#     plane_spacing=235,
#     max_cut_speed_mm_s=180,
#     min_cut_speed_mm_s=100,
#     decomposer = Decomposer(buffer=0.5)
# ).with_recentered_part()
# gcode = ms.prepare_gcode()
# ms.plot()

# %%
# Again
# from airfoil.cnc import MachineSetup, CNC
# ms = MachineSetup(
#     wing_segment=ws4,
#     foam_depth=200,
#     foam_height=100,
#     plane_spacing=235,
#     max_cut_speed_mm_s=180,
#     min_cut_speed_mm_s=100,
#     decomposer = Decomposer(buffer=0.5)
# ).with_recentered_part()
# gcode = ms.prepare_gcode()
# ms.plot()

# %%
# from airfoil.cnc import MachineSetup, CNC
# ms = MachineSetup(
#     wing_segment=ws3,
#     foam_depth=200,
#     foam_height=30,
#     plane_spacing=235,
#     max_cut_speed_mm_s=180,
#     min_cut_speed_mm_s=100,
#     decomposer = Decomposer(buffer=0.5)
# ).with_recentered_part()
# gcode = ms.prepare_gcode()
# ms.plot()

# %%
# from airfoil.cnc import MachineSetup, CNC
# ms = MachineSetup(
#     wing_segment=ws5,
#     foam_depth=170,
#     foam_height=30,
#     plane_spacing=235,
#     max_cut_speed_mm_s=180,
#     min_cut_speed_mm_s=100,
#     decomposer = Decomposer(buffer=0.5)
# ).with_recentered_part()
# gcode = ms.prepare_gcode()
# ms.plot()

# %%
cnc = CNC()

# %%
cnc.alarm_soft_reset()
cnc.alarm_clear()
cnc.alarm_soft_reset()

# %%
# first homing
cnc.home()
cnc.relative()
cnc.travel(
    100,100,
    100,100,
)

# %%
cnc.relative()
cnc.travel(
    0,-0.5,
    0,-0.5,
)

# %%
cnc.set_position(0,0,0,0)
cnc.absolute()
cnc.dwel(4)
cnc.send_gcode_lines(gcode.split("\r\n"))

# %%
cnc.set_current(0)

# %%
cnc.absolute()
cnc.travel(0,0,0,0)
